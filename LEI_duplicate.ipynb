# %%
# !pip install fuzzywuzzy==0.18.0
# !pip install wget==3.2
# !pip install plotly==5.6.0
# Out:
# Requirement already satisfied: fuzzywuzzy==0.18.0 in /Users/uyenle/opt/anaconda3/lib/python3.9/site-packages (0.18.0)
# Requirement already satisfied: wget==3.2 in /Users/uyenle/opt/anaconda3/lib/python3.9/site-packages (3.2)
# Requirement already satisfied: plotly==5.6.0 in /Users/uyenle/opt/anaconda3/lib/python3.9/site-packages (5.6.0)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/uyenle/opt/anaconda3/lib/python3.9/site-packages (from plotly==5.6.0) (8.0.1)
# Requirement already satisfied: six in /Users/uyenle/opt/anaconda3/lib/python3.9/site-packages (from plotly==5.6.0) (1.16.0)

# %%
import wget

wget.download('https://leidata-preview.gleif.org/storage/golden-copy-files/2022/04/01/617937/20220401-0800-gleif-goldencopy-lei2-golden-copy.csv.zip#')
wget.download('https://leidata-preview.gleif.org/storage/golden-copy-files/2022/04/01/617985/20220401-0800-gleif-goldencopy-rr-golden-copy.csv.zip#')
# Out:
# '20220401-0800-gleif-goldencopy-rr-golden-copy.csv.zip'

# %%
import pandas as pd
import plotly.express as px
col = ['LEI',
        'Entity.LegalName',
        'Entity.LegalJurisdiction',
        'Entity.LegalForm.EntityLegalFormCode',
        'Entity.EntityStatus',
        'Entity.RegistrationAuthority.RegistrationAuthorityEntityID',
        'Entity.EntityCategory',
        'Registration.RegistrationStatus',
        'Registration.LastUpdateDate' ]

data = pd.read_csv('20220401-0800-gleif-goldencopy-lei2-golden-copy.csv.zip', compression='zip', usecols = col,dtype='unicode')
data_rr = pd.read_csv('20220401-0800-gleif-goldencopy-rr-golden-copy.csv.zip',compression='zip',dtype='unicode')

# %% [markdown]
# # Exe 1: Public Limited Companies (PLCs) in Great Britain

# %%
#Entity.LegalForm.EntityLegalFormCode = ‘B6ES’
plc_gb = data[data['Entity.LegalForm.EntityLegalFormCode']=='B6ES'].drop_duplicates()
plc_gb = plc_gb.applymap(str)
plc_gb.head()
# Out:
#                        LEI            Entity.LegalName  \
# 3626  0TMBS544NMO7GLCE7H90                   ABRDN PLC
# 4275  2138001123F8QFPOZ919  TANGENT COMMUNICATIONS PLC
# 4313  21380011BEY3JSQ3AU68       PARSLEY BOX GROUP PLC
# 4325  21380011EU95E93AQN91            SULNOX GROUP PLC
# 4352  21380011L2Y2O7QAFQ89        NORTHERN & SHELL PLC
#
#      Entity.RegistrationAuthority.RegistrationAuthorityEntityID  \
# 3626                                           SC286832
# 4275                                           03967805
# 4313                                           SC685656
# 4325                                           08449586
# 4352                                           04086466
#
#      Entity.LegalJurisdiction Entity.EntityCategory  \
# 3626                       GB               GENERAL
# 4275                       GB               GENERAL
# 4313                       GB               GENERAL
# 4325                       GB               GENERAL
# 4352                       GB               GENERAL
#
#      Entity.LegalForm.EntityLegalFormCode Entity.EntityStatus  \
# 3626                                 B6ES              ACTIVE
# 4275                                 B6ES              ACTIVE
# 4313                                 B6ES              ACTIVE
# 4325                                 B6ES              ACTIVE
# 4352                                 B6ES              ACTIVE
#
#      Registration.LastUpdateDate Registration.RegistrationStatus
# 3626    2022-03-28T14:21:02.157Z                          ISSUED
# 4275    2019-01-15T13:19:01.703Z                          LAPSED
# 4313    2022-03-22T04:13:11.243Z                          ISSUED
# 4325    2022-03-22T04:13:43.710Z                          ISSUED
# 4352    2021-05-14T12:18:16.910Z                          ISSUED

# %%
plc_gb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4114 entries, 3626 to 2105045
# Data columns (total 9 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   LEI                                                         4114 non-null   object
#  1   Entity.LegalName                                            4114 non-null   object
#  2   Entity.RegistrationAuthority.RegistrationAuthorityEntityID  4114 non-null   object
#  3   Entity.LegalJurisdiction                                    4114 non-null   object
#  4   Entity.EntityCategory                                       4114 non-null   object
#  5   Entity.LegalForm.EntityLegalFormCode                        4114 non-null   object
#  6   Entity.EntityStatus                                         4114 non-null   object
#  7   Registration.LastUpdateDate                                 4114 non-null   object
#  8   Registration.RegistrationStatus                             4114 non-null   object
# dtypes: object(9)
# memory usage: 321.4+ KB

# %% [markdown]
# # Exe 2: Visualize the EntityStatus and RegistrationStatus from exercise 1

# %% [markdown]
# **Entity.EntityStatus:**
#
# ACTIVE - As of the last report or update, the Legal Entity reported that it was legally registered and operating.
#
# INACTIVE - It has been determined that the Entity that was assigned the LEI is no longer legally registered and/or operating, whether as a result of business closure, acquisition by or merger with another (or new) Entity, or determination of illegitimacy.
#
# new NULL - The entity status is not applicable.
#
# **Registration.RegistrationStatus**
#
# PENDING_VALIDATION - An application for an LEI that has been submitted and which is being processed and validated
#
# ISSUED - An LEI Registration that has been validated and issued, and which identifies an Entity that was an operating Legal Entity as of the last update
#
# DUPLICATE - An LEI Registration that has been determined to be a duplicate registration of the same Legal Entity as another LEI Registration; the DUPLICATE status is assigned to the non-surviving registration (i.e. the LEI that should no longer be used)
#
# LAPSED - An LEI registration that has not been renewed by the NextRenewalDate and is not known by public sources to have ceased operation
#
# deprecated MERGED - An LEI registration for an Entity that has been merged into another Legal Entity, such that this Legal Entity no longer exists as an operating Entity
#
# RETIRED - An LEI registration for an Entity that has ceased operation, without having been merged into another Entity
#
# ANNULLED - An LEI registration that was marked as erroneous or invalid after it was issued
#
# CANCELLED - An LEI registration that was abandoned prior to issuance of an LEI
# TRANSFERRED - An LEI registration that has been transferred to a different LOU as the managing LOU
#
# PENDING_TRANSFER - An LEI registration that has been requested to be transferred to another LOU. The request is being processed at the sending LOU
#
# PENDING_ARCHIVAL - An LEI registration is about to be transferred to a different LOU, after which its registration status will revert to a non-pending status

# %%
fig = px.histogram(data_frame=plc_gb,
                    x='Entity.EntityStatus', 
                    color='Registration.RegistrationStatus',
                    text_auto=True,
                    barmode='stack',
                    histfunc='count')

fig.update_layout(title = 'EntityStatus and RegistrationStatus relationship',
                  xaxis_title="Entity Status",
                  yaxis_title="TotalRegistration Status", 
                  legend_title='Registration Status')
fig.show()

# %% [markdown]
# **How do the fields EntityStatus and RegistrationStatus are related to each other?**
#
# * RegistrationStatus of ISSUED (validated and issued registration) and LAPSED (unknown renewal) are labeled ACTIVE EntityStatus.
# * RegistrationStatus of RETIRED (ceased operation) is labeled INACTIVE EntityStatus
# * RegistrationStatus of DUPLICATED (same legal entity) is labeled NULL Entity Status

# %%
#Check overall relationship
data[['Entity.EntityStatus']] = data[['Entity.EntityStatus']].fillna('NULL')
data[['Entity.EntityStatus','Registration.RegistrationStatus']].groupby(['Entity.EntityStatus','Registration.RegistrationStatus']).count()
# Out:
# Empty DataFrame
# Columns: []
# Index: [(ACTIVE, ISSUED), (ACTIVE, LAPSED), (ACTIVE, PENDING_ARCHIVAL), (ACTIVE, PENDING_TRANSFER), (INACTIVE, RETIRED), (NULL, ANNULLED), (NULL, DUPLICATE), (NULL, ISSUED), (NULL, PENDING_TRANSFER)]

# %% [markdown]
# # Exe 3: Find the ultimate parents of all entities from exercise 1

# %% [markdown]
# **Relationship.RelationshipType**
#
# IS_DIRECTLY_CONSOLIDATED_BY - The StartNode of the "child" entity has its accounts fully consolidated by the EndNode "parent" entity, in the sense given by the accounting standard(s) specified in RelationshipQualifiers;the EndNode entity is the closest fully consolidating parent to the StartNode entity in any applicable hierarchical ownership structure.
#
# IS_ULTIMATELY_CONSOLIDATED_BY - The StartNode "child" entity has its accounts fully consolidated by the EndNode "parent" entity, in the sense given by the accounting standard(s) specified in the RelationshipQualifiers; the EndNode entity is the most distant fully consolidating parent from the StartNode entity in any applicable hierarchical ownership structure.
#
# IS_INTERNATIONAL_BRANCH_OF - The StartNode is an international branch of the legal entity designated by EndNode (in jurisdiction country of StartNode). The EndNode is the Head Office and SHALL be an LEI.
#
# IS_FUND-MANAGED_BY - The StartNode is a fund managed by a main management entity. The EndNode is legally responsible for the constitution and operation of the fund.
#
# IS_SUBFUND_OF - The StartNode is a sub-fund to an umbrella fund. The EndNode is a legal entity with one or more than one sub-funds/compartments where each sub-fund/compartment has its own investment objectives, separate investment policies and strategies, segregation of assets, separate investors and which has segregated liability between sub-funds/compartments.
#
# IS_FEEDER_TO - The StartNode is a Feeder Fund,that is (almost) exclusively invested in a single other fund. The EndNode is the Master Fund that has identical investment strategies.

# %%
#LEI can be found in RR database
all_rr_id = pd.concat([data_rr['Relationship.EndNode.NodeID'], data_rr['Relationship.StartNode.NodeID']]).drop_duplicates().tolist()
plc_gb_filter = plc_gb[plc_gb['LEI'].isin(all_rr_id)]
plc_gb_filter.head()
# Out:
#                        LEI               Entity.LegalName  \
# 3626  0TMBS544NMO7GLCE7H90                      ABRDN PLC
# 4275  2138001123F8QFPOZ919     TANGENT COMMUNICATIONS PLC
# 4352  21380011L2Y2O7QAFQ89           NORTHERN & SHELL PLC
# 4470  21380012AJC5OQUSKX05  PARAGON MORTGAGES (NO.15) PLC
# 4741  21380013V6JI2T3MOG16       HAMPSHIRE TRUST BANK PLC
#
#      Entity.RegistrationAuthority.RegistrationAuthorityEntityID  \
# 3626                                           SC286832
# 4275                                           03967805
# 4352                                           04086466
# 4470                                           06212267
# 4741                                           01311315
#
#      Entity.LegalJurisdiction Entity.EntityCategory  \
# 3626                       GB               GENERAL
# 4275                       GB               GENERAL
# 4352                       GB               GENERAL
# 4470                       GB               GENERAL
# 4741                       GB               GENERAL
#
#      Entity.LegalForm.EntityLegalFormCode Entity.EntityStatus  \
# 3626                                 B6ES              ACTIVE
# 4275                                 B6ES              ACTIVE
# 4352                                 B6ES              ACTIVE
# 4470                                 B6ES              ACTIVE
# 4741                                 B6ES              ACTIVE
#
#      Registration.LastUpdateDate Registration.RegistrationStatus
# 3626    2022-03-28T14:21:02.157Z                          ISSUED
# 4275    2019-01-15T13:19:01.703Z                          LAPSED
# 4352    2021-05-14T12:18:16.910Z                          ISSUED
# 4470    2021-02-28T00:05:11.030Z                          LAPSED
# 4741    2021-10-12T13:22:18.730Z                          ISSUED

# %%
#LEI can not be found in RR database: no record in level 2 data
print("{} LEIs don't have Relationship records".format(plc_gb.shape[0]-plc_gb_filter.shape[0]))
# Out:
# 2869 LEIs don't have Relationship records

# %%
#Relationship.RelationshipType ==  ‘IS_ULTIMATELY_CONSOLIDATED_BY’.
data_rr_filter = data_rr.loc[(data_rr['Relationship.RelationshipType']=='IS_ULTIMATELY_CONSOLIDATED_BY')].drop_duplicates()
data_rr_filter = data_rr_filter.applymap(str)

# %%
#LEI that can be found in StartNode
in_start_node = pd.merge(plc_gb_filter[['LEI']], data_rr_filter, left_on='LEI', right_on='Relationship.StartNode.NodeID', how='inner')
print("{} LEIs are the StartNode to their ultimate parent, including case StartNodeID == EndNodeID".format(in_start_node.shape[0]))
in_start_node.head()
# Out:
# 608 LEIs are the StartNode to their ultimate parent, including case StartNodeID == EndNodeID
#                     LEI Relationship.StartNode.NodeID  \
# 0  21380012AJC5OQUSKX05          21380012AJC5OQUSKX05
# 1  21380013V6JI2T3MOG16          21380013V6JI2T3MOG16
# 2  21380018AJDKNF3A6712          21380018AJDKNF3A6712
# 3  2138001GRMZ39JRSE316          2138001GRMZ39JRSE316
# 4  2138001JRCRN7WGSM347          2138001JRCRN7WGSM347
#
#   Relationship.StartNode.NodeIDType Relationship.EndNode.NodeID  \
# 0                               LEI        213800S1TDKIB1IUTS72
# 1                               LEI        213800K3UGDI64TUAH80
# 2                               LEI        2138002P5RNKC5W2JZ46
# 3                               LEI        549300O5FACQ67KI6R92
# 4                               LEI        WXD0EHQRPI7HKN3I5T57
#
#   Relationship.EndNode.NodeIDType  Relationship.RelationshipType  \
# 0                             LEI  IS_ULTIMATELY_CONSOLIDATED_BY
# 1                             LEI  IS_ULTIMATELY_CONSOLIDATED_BY
# 2                             LEI  IS_ULTIMATELY_CONSOLIDATED_BY
# 3                             LEI  IS_ULTIMATELY_CONSOLIDATED_BY
# 4                             LEI  IS_ULTIMATELY_CONSOLIDATED_BY
#
#   Relationship.RelationshipStatus Relationship.Period.1.startDate  \
# 0                          ACTIVE            2016-10-01T00:00:00Z
# 1                          ACTIVE            2020-01-01T00:00:00Z
# 2                          ACTIVE            2019-03-01T00:00:00Z
# 3                          ACTIVE            2020-04-01T00:00:00Z
# 4                          ACTIVE            2020-01-01T00:00:00Z
#
#   Relationship.Period.1.endDate Relationship.Period.1.periodType  ...  \
# 0          2017-09-30T00:00:00Z                ACCOUNTING_PERIOD  ...
# 1          2020-12-31T00:00:00Z                ACCOUNTING_PERIOD  ...
# 2          2020-02-29T00:00:00Z                ACCOUNTING_PERIOD  ...
# 3          2021-03-31T00:00:00Z                ACCOUNTING_PERIOD  ...
# 4          2020-12-31T00:00:00Z                ACCOUNTING_PERIOD  ...
#
#   Relationship.Quantifiers.5.QuantifierAmount  \
# 0                                         nan
# 1                                         nan
# 2                                         nan
# 3                                         nan
# 4                                         nan
#
#   Relationship.Quantifiers.5.QuantifierUnits  \
# 0                                        nan
# 1                                        nan
# 2                                        nan
# 3                                        nan
# 4                                        nan
#
#   Registration.InitialRegistrationDate Registration.LastUpdateDate  \
# 0                 2014-02-24T00:00:00Z    2021-02-28T00:05:11.030Z
# 1                 2014-11-27T00:00:00Z    2021-10-12T13:22:18.730Z
# 2                 2013-12-19T00:00:00Z    2021-11-16T13:41:18.493Z
# 3                 2014-02-18T00:00:00Z    2022-03-21T13:28:11.730Z
# 4                 2019-05-20T00:00:00Z    2022-03-25T06:16:18.177Z
#
#   Registration.RegistrationStatus Registration.NextRenewalDate  \
# 0                          LAPSED         2021-02-27T00:00:00Z
# 1                       PUBLISHED         2022-11-27T00:00:00Z
# 2                       PUBLISHED         2023-01-09T00:00:00Z
# 3                       PUBLISHED         2023-03-16T00:00:00Z
# 4                       PUBLISHED         2023-05-20T00:00:00Z
#
#   Registration.ManagingLOU Registration.ValidationSources  \
# 0     213800WAVVOPS85N2205             FULLY_CORROBORATED
# 1     213800WAVVOPS85N2205             FULLY_CORROBORATED
# 2     213800WAVVOPS85N2205             FULLY_CORROBORATED
# 3     213800WAVVOPS85N2205             FULLY_CORROBORATED
# 4     213800WAVVOPS85N2205             FULLY_CORROBORATED
#
#   Registration.ValidationDocuments  \
# 0                  ACCOUNTS_FILING
# 1                  ACCOUNTS_FILING
# 2                  ACCOUNTS_FILING
# 3                  ACCOUNTS_FILING
# 4                  ACCOUNTS_FILING
#
#                     Registration.ValidationReference
# 0  https://beta.companieshouse.gov.uk/company/062...
# 1  https://find-and-update.company-information.se...
# 2  https://www.tescoplc.com/media/755761/tes006_a...
# 3  https://find-and-update.company-information.se...
# 4  https://www.ybs.co.uk/pdfs/financial-results/a...
#
# [5 rows x 55 columns]

# %%
# Series of LEI can not be found in StartNode
not_in_start_node = plc_gb_filter[~plc_gb_filter['LEI'].isin(in_start_node['Relationship.StartNode.NodeID'])]

# LEI is in EndNode: are ultimate parents of their Child Entities
in_end_node = pd.merge(not_in_start_node[['LEI']], data_rr_filter, left_on='LEI', right_on='Relationship.EndNode.NodeID', how='inner')
in_end_node = in_end_node.groupby('LEI').agg({lambda x: ', '.join((set(x)))})
in_end_node.columns = in_end_node.columns.get_level_values(0)
in_end_node = in_end_node.reset_index()
print("{} LEIs are the EndNode, e.i. the ultimate parents of their child entities".format(in_end_node.shape[0]))
in_end_node.head()
# Out:
# 559 LEIs are the EndNode, e.i. the ultimate parents of their child entities
#                     LEI                      Relationship.StartNode.NodeID  \
# 0  0TMBS544NMO7GLCE7H90  549300JQ4E2V16CGLN33, 2138001I1CXGD29OLB60, 54...
# 1  213800167WOVOK5ZC776                               213800H4GKEF3CJ8C774
# 2  21380016X1OWIRVRSI65                               213800HZXY86ZJ7KA323
# 3  2138001AVBSD1HSC6Z10  2138009C97IBNLCEIP38, 2138006EGNJJ4L6S6987, 21...
# 4  2138001I27OUBAF22K83                               213800EIVRN53COLPP92
#
#   Relationship.StartNode.NodeIDType Relationship.EndNode.NodeID  \
# 0                               LEI        0TMBS544NMO7GLCE7H90
# 1                               LEI        213800167WOVOK5ZC776
# 2                               LEI        21380016X1OWIRVRSI65
# 3                               LEI        2138001AVBSD1HSC6Z10
# 4                               LEI        2138001I27OUBAF22K83
#
#   Relationship.EndNode.NodeIDType  Relationship.RelationshipType  \
# 0                             LEI  IS_ULTIMATELY_CONSOLIDATED_BY
# 1                             LEI  IS_ULTIMATELY_CONSOLIDATED_BY
# 2                             LEI  IS_ULTIMATELY_CONSOLIDATED_BY
# 3                             LEI  IS_ULTIMATELY_CONSOLIDATED_BY
# 4                             LEI  IS_ULTIMATELY_CONSOLIDATED_BY
#
#   Relationship.RelationshipStatus  \
# 0                          ACTIVE
# 1                          ACTIVE
# 2                          ACTIVE
# 3                          ACTIVE
# 4                          ACTIVE
#
#                      Relationship.Period.1.startDate  \
# 0  2018-10-01T00:00:00Z, 2014-01-21T00:00:00Z, 20...
# 1                               2020-01-01T00:00:00Z
# 2                               2019-10-06T00:00:00Z
# 3  2020-04-01T00:00:00Z, 2002-09-05T18:30:00.001Z...
# 4                               2020-01-01T00:00:00Z
#
#                        Relationship.Period.1.endDate  \
# 0  2020-12-31T00:00:00Z, 2019-09-30T00:00:00Z, 20...
# 1                               2020-12-31T00:00:00Z
# 2                               2020-10-03T00:00:00Z
# 3    nan, 2021-03-31T00:00:00Z, 2019-03-31T00:00:00Z
# 4                               2020-12-31T00:00:00Z
#
#          Relationship.Period.1.periodType  ...  \
# 0  RELATIONSHIP_PERIOD, ACCOUNTING_PERIOD  ...
# 1                       ACCOUNTING_PERIOD  ...
# 2                       ACCOUNTING_PERIOD  ...
# 3  RELATIONSHIP_PERIOD, ACCOUNTING_PERIOD  ...
# 4                       ACCOUNTING_PERIOD  ...
#
#   Relationship.Quantifiers.5.QuantifierAmount  \
# 0                                         nan
# 1                                         nan
# 2                                         nan
# 3                                         nan
# 4                                         nan
#
#   Relationship.Quantifiers.5.QuantifierUnits  \
# 0                                        nan
# 1                                        nan
# 2                                        nan
# 3                                        nan
# 4                                        nan
#
#                 Registration.InitialRegistrationDate  \
# 0  2017-09-18T00:00:00Z, 2018-10-30T00:00:00Z, 20...
# 1                               2019-09-09T00:00:00Z
# 2                               2017-09-27T00:00:00Z
# 3  2021-11-19T10:03:04.127Z, 2016-12-13T00:00:00Z...
# 4                               2021-12-07T00:00:00Z
#
#                          Registration.LastUpdateDate  \
# 0  2021-09-27T13:42:22.107Z, 2021-09-27T12:40:07....
# 1                           2021-10-29T12:44:22.907Z
# 2                           2021-08-04T09:38:07.120Z
# 3  2019-11-19T15:46:06.680Z, 2021-11-19T10:03:04....
# 4                           2021-12-07T07:41:10.633Z
#
#   Registration.RegistrationStatus  \
# 0               LAPSED, PUBLISHED
# 1                       PUBLISHED
# 2                       PUBLISHED
# 3               LAPSED, PUBLISHED
# 4                       PUBLISHED
#
#                         Registration.NextRenewalDate  \
# 0  2023-04-03T00:00:00Z, 2022-11-29T00:00:00Z, 20...
# 1                               2022-10-28T00:00:00Z
# 2                               2022-09-28T00:00:00Z
# 3  2023-01-24T00:00:00Z, 2020-01-08T00:00:00Z, 20...
# 4                               2022-12-07T00:00:00Z
#
#                             Registration.ManagingLOU  \
# 0  EVK05KS7XY1DEII3R011, 213800WAVVOPS85N2205, 54...
# 1                               213800WAVVOPS85N2205
# 2                               213800WAVVOPS85N2205
# 3         213800WAVVOPS85N2205, 335800FVH4MOKZS9VH40
# 4                               213800WAVVOPS85N2205
#
#              Registration.ValidationSources  \
# 0  ENTITY_SUPPLIED_ONLY, FULLY_CORROBORATED
# 1                        FULLY_CORROBORATED
# 2                        FULLY_CORROBORATED
# 3  ENTITY_SUPPLIED_ONLY, FULLY_CORROBORATED
# 4                        FULLY_CORROBORATED
#
#                     Registration.ValidationDocuments  \
# 0  OTHER_OFFICIAL_DOCUMENTS, REGULATORY_FILING, A...
# 1                                    ACCOUNTS_FILING
# 2                                    ACCOUNTS_FILING
# 3                                    ACCOUNTS_FILING
# 4                                    ACCOUNTS_FILING
#
#                     Registration.ValidationReference
# 0  https://www.aberdeenstandard.com/docs?editionI...
# 1  https://find-and-update.company-information.se...
# 2  https://find-and-update.company-information.se...
# 3  URL not publicly available, validated from doc...
# 4  https://find-and-update.company-information.se...
#
# [5 rows x 55 columns]

# %%
# RR database contains 'Relationship.RelationshipType' other than 'IS_ULTIMATELY_CONSOLIDATED_BY'
anti_data_rr_filter = data_rr.loc[(data_rr['Relationship.RelationshipType']!='IS_ULTIMATELY_CONSOLIDATED_BY')]

#Series of LEI can not be found in Start or EndNode of 'IS_ULTIMATELY_CONSOLIDATED_BY' relationship
not_ultimate_relationship = not_in_start_node[~not_in_start_node['LEI'].isin(in_end_node['LEI'])]

# %%
#LEI {other relationship} EndNode == StartNode {Ultimate Parent} EndNode
not_ultimate_rr_in_start_node = pd.merge(not_ultimate_relationship[['LEI']], anti_data_rr_filter, left_on='LEI', right_on='Relationship.StartNode.NodeID', how='inner')

print("{} LEIs are the StartNode in relationships other that ultimare child-parent".format(in_end_node.shape[0]))
not_ultimate_rr_in_start_node.head()
# Out:
# 559 LEIs are the StartNode in relationships other that ultimare child-parent
#                     LEI Relationship.StartNode.NodeID  \
# 0  2138009GN3HVIT9T1Z72          2138009GN3HVIT9T1Z72
# 1  2138009ZH1J2B1MR1D80          2138009ZH1J2B1MR1D80
# 2  213800DL377MH46PDY63          213800DL377MH46PDY63
# 3  213800ESMPQ4RQ7G8351          213800ESMPQ4RQ7G8351
# 4  213800F7AYNHLL1BPR31          213800F7AYNHLL1BPR31
#
#   Relationship.StartNode.NodeIDType Relationship.EndNode.NodeID  \
# 0                               LEI        391200IHCFFNDBNLG964
# 1                               LEI        549300M46A841BTWC767
# 2                               LEI        213800ZD31YIOEE51B19
# 3                               LEI        213800JKM5UQHFJOTZ25
# 4                               LEI        549300TJPP85XH21TK11
#
#   Relationship.EndNode.NodeIDType Relationship.RelationshipType  \
# 0                             LEI   IS_DIRECTLY_CONSOLIDATED_BY
# 1                             LEI   IS_DIRECTLY_CONSOLIDATED_BY
# 2                             LEI   IS_DIRECTLY_CONSOLIDATED_BY
# 3                             LEI   IS_DIRECTLY_CONSOLIDATED_BY
# 4                             LEI   IS_DIRECTLY_CONSOLIDATED_BY
#
#   Relationship.RelationshipStatus Relationship.Period.1.startDate  \
# 0                          ACTIVE            2019-01-01T00:00:00Z
# 1                          ACTIVE            2015-06-16T00:00:00Z
# 2                          ACTIVE            2019-04-01T00:00:00Z
# 3                          ACTIVE            2020-04-01T00:00:00Z
# 4                          ACTIVE            2020-07-01T00:00:00Z
#
#   Relationship.Period.1.endDate Relationship.Period.1.periodType  ...  \
# 0          2019-12-31T00:00:00Z                ACCOUNTING_PERIOD  ...
# 1                           NaN                ACCOUNTING_PERIOD  ...
# 2          2020-03-31T00:00:00Z                ACCOUNTING_PERIOD  ...
# 3          2021-03-31T00:00:00Z                ACCOUNTING_PERIOD  ...
# 4          2021-06-30T00:00:00Z                ACCOUNTING_PERIOD  ...
#
#   Relationship.Quantifiers.5.QuantifierAmount  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#   Relationship.Quantifiers.5.QuantifierUnits  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#   Registration.InitialRegistrationDate Registration.LastUpdateDate  \
# 0                 2015-02-05T00:00:00Z    2021-12-10T07:08:35.580Z
# 1                 2015-06-16T00:00:00Z    2018-05-04T12:03:10.240Z
# 2                 2014-01-29T00:00:00Z    2022-02-02T11:17:44.200Z
# 3                 2014-01-29T00:00:00Z    2022-03-11T13:47:58.980Z
# 4                 2018-01-15T00:00:00Z    2022-01-18T09:48:08.110Z
#
#   Registration.RegistrationStatus Registration.NextRenewalDate  \
# 0                       PUBLISHED         2023-02-05T00:00:00Z
# 1                       PUBLISHED         2019-06-16T00:00:00Z
# 2                       PUBLISHED         2023-03-02T00:00:00Z
# 3                       PUBLISHED         2023-03-11T00:00:00Z
# 4                       PUBLISHED         2023-01-18T00:00:00Z
#
#   Registration.ManagingLOU Registration.ValidationSources  \
# 0     213800WAVVOPS85N2205             FULLY_CORROBORATED
# 1     213800WAVVOPS85N2205           ENTITY_SUPPLIED_ONLY
# 2     213800WAVVOPS85N2205             FULLY_CORROBORATED
# 3     213800WAVVOPS85N2205             FULLY_CORROBORATED
# 4     213800WAVVOPS85N2205             FULLY_CORROBORATED
#
#   Registration.ValidationDocuments  \
# 0                  ACCOUNTS_FILING
# 1         OTHER_OFFICIAL_DOCUMENTS
# 2                  ACCOUNTS_FILING
# 3                  ACCOUNTS_FILING
# 4                  ACCOUNTS_FILING
#
#                     Registration.ValidationReference
# 0  https://find-and-update.company-information.se...
# 1                                                NaN
# 2  https://find-and-update.company-information.se...
# 3  https://find-and-update.company-information.se...
# 4  https://find-and-update.company-information.se...
#
# [5 rows x 55 columns]

# %%
not_ultimate_rr_in_start_node_list = not_ultimate_rr_in_start_node['LEI'].tolist()
not_ultimate_rr_in_start_node_anti = not_ultimate_relationship[~not_ultimate_relationship['LEI'].isin(not_ultimate_rr_in_start_node_list)]

not_ultimate_rr_in_end_node = pd.merge(not_ultimate_rr_in_start_node_anti[['LEI']], anti_data_rr_filter, left_on='LEI', right_on='Relationship.EndNode.NodeID', how='inner')
not_ultimate_rr_in_end_node = not_ultimate_rr_in_end_node.groupby('LEI').agg({lambda x: ', '.join((set(x)))})
not_ultimate_rr_in_end_node.columns = not_ultimate_rr_in_end_node.columns.get_level_values(0)
not_ultimate_rr_in_end_node = not_ultimate_rr_in_end_node.reset_index()
print("{} LEIs are the EndNode in relationships other that ultimare child-parent".format(not_ultimate_rr_in_end_node.shape[0]))
not_ultimate_rr_in_end_node.head()
# Out:
# 41 LEIs are the EndNode in relationships other that ultimare child-parent
# /Users/uyenle/opt/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/generic.py:303: FutureWarning:
#
# Dropping invalid columns in SeriesGroupBy.agg is deprecated. In a future version, a TypeError will be raised. Before calling .agg, select only columns which should be valid for the aggregating function.
#                     LEI               Relationship.StartNode.NodeID  \
# 0  2138001123F8QFPOZ919                        9845009B3D5759E3D209
# 1  21380011L2Y2O7QAFQ89                        2138001B486RXXI3FA30
# 2  2138002P98CV22GBM646                        213800U1HNQMN9S7PQ90
# 3  2138003SD721TYSR3731                        213800YFRLD1UJ1DIB54
# 4  2138004N53RFLL6JDQ41  213800DZ5XY8AG5COI19, 21380017NR49F34PWQ94
#
#   Relationship.StartNode.NodeIDType Relationship.EndNode.NodeID  \
# 0                               LEI        2138001123F8QFPOZ919
# 1                               LEI        21380011L2Y2O7QAFQ89
# 2                               LEI        2138002P98CV22GBM646
# 3                               LEI        2138003SD721TYSR3731
# 4                               LEI        2138004N53RFLL6JDQ41
#
#   Relationship.EndNode.NodeIDType Relationship.RelationshipType  \
# 0                             LEI   IS_DIRECTLY_CONSOLIDATED_BY
# 1                             LEI   IS_DIRECTLY_CONSOLIDATED_BY
# 2                             LEI   IS_DIRECTLY_CONSOLIDATED_BY
# 3                             LEI   IS_DIRECTLY_CONSOLIDATED_BY
# 4                             LEI   IS_DIRECTLY_CONSOLIDATED_BY
#
#   Relationship.RelationshipStatus Relationship.Period.1.startDate  \
# 0                          ACTIVE       2019-03-31T00:00:00+00:00
# 1                          ACTIVE            2018-05-29T00:00:00Z
# 2                          ACTIVE            2020-04-01T00:00:00Z
# 3                          ACTIVE            2019-04-01T00:00:00Z
# 4                          ACTIVE            2020-01-01T00:00:00Z
#
#   Relationship.Period.1.periodType  \
# 0                ACCOUNTING_PERIOD
# 1                ACCOUNTING_PERIOD
# 2                ACCOUNTING_PERIOD
# 3                ACCOUNTING_PERIOD
# 4                ACCOUNTING_PERIOD
#
#          Registration.InitialRegistrationDate  \
# 0                   2020-04-14T10:05:41+00:00
# 1                        2018-05-29T00:00:00Z
# 2                        2017-11-13T00:00:00Z
# 3                        2016-10-10T00:00:00Z
# 4  2018-07-12T00:00:00Z, 2020-03-11T00:00:00Z
#
#                          Registration.LastUpdateDate  \
# 0                          2022-02-23T15:28:33+00:00
# 1                           2018-05-29T08:34:10.437Z
# 2                           2021-11-22T11:59:27.800Z
# 3                           2021-08-13T16:34:56.460Z
# 4  2022-03-01T16:08:40.823Z, 2021-07-01T14:49:19....
#
#   Registration.RegistrationStatus                Registration.NextRenewalDate  \
# 0                       PUBLISHED                   2022-04-14T09:34:10+00:00
# 1                       PUBLISHED                        2019-05-29T00:00:00Z
# 2                       PUBLISHED                        2022-11-22T00:00:00Z
# 3                       PUBLISHED                        2022-10-10T00:00:00Z
# 4                       PUBLISHED  2022-07-15T00:00:00Z, 2023-03-11T00:00:00Z
#
#   Registration.ManagingLOU            Registration.ValidationSources  \
# 0     529900T8BM49AURSDO55                        FULLY_CORROBORATED
# 1     213800WAVVOPS85N2205                        FULLY_CORROBORATED
# 2     213800WAVVOPS85N2205                        FULLY_CORROBORATED
# 3     213800WAVVOPS85N2205                        FULLY_CORROBORATED
# 4     213800WAVVOPS85N2205  ENTITY_SUPPLIED_ONLY, FULLY_CORROBORATED
#
#         Registration.ValidationDocuments
# 0                        ACCOUNTS_FILING
# 1                        ACCOUNTS_FILING
# 2                        ACCOUNTS_FILING
# 3                        ACCOUNTS_FILING
# 4  ACCOUNTS_FILING, SUPPORTING_DOCUMENTS

# %% [markdown]
# # Exe 4: Identify potential duplicates in Great Britain

# %%
import numpy as np
from itertools import product, combinations_with_replacement
from nltk.metrics import *
from fuzzywuzzy import fuzz
# Out:
# /Users/uyenle/opt/anaconda3/lib/python3.9/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning:
#
# Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning

# %%
test_data= plc_gb[['LEI','Entity.LegalName','Registration.RegistrationStatus']]
test_data.head()
# Out:
#                        LEI            Entity.LegalName  \
# 3626  0TMBS544NMO7GLCE7H90                   ABRDN PLC
# 4275  2138001123F8QFPOZ919  TANGENT COMMUNICATIONS PLC
# 4313  21380011BEY3JSQ3AU68       PARSLEY BOX GROUP PLC
# 4325  21380011EU95E93AQN91            SULNOX GROUP PLC
# 4352  21380011L2Y2O7QAFQ89        NORTHERN & SHELL PLC
#
#      Registration.RegistrationStatus
# 3626                          ISSUED
# 4275                          LAPSED
# 4313                          ISSUED
# 4325                          ISSUED
# 4352                          ISSUED

# %%
dup_test_data = test_data[test_data['Registration.RegistrationStatus']=='DUPLICATE']
print("{} Duplicates in database.".format(dup_test_data.shape[0]))
dup_test_data
# Out:
# 10 Duplicates in database.
#                           LEI                          Entity.LegalName  \
# 92756    213800GBJ1RNNUKP2182                                OROGEN PLC
# 110511   213800JEFWNMHV4VS596                         TOPAZ FINANCE PLC
# 117233   213800KJWSAW2912ZP76  MANCHESTER & LONDON INVESTMENT TRUST PLC
# 140006   213800OIN8T68PM7HK77                             N4 PHARMA PLC
# 769036   5493001W2FMNF0GV7B53                            Renishaw P L C
# 769424   5493001WZIZE0GTD2X45       Tobermore Concrete Products Limited
# 994623   549300HXJ164L1L8IM53                      President Energy PLC
# 1067553  549300MSQV80HSATBG53     Vodafone Group Public Limited Company
# 1190418  549300V0DVQGSADLDB82                         Bristol Water PLC
# 1729864  8YXIFWJW5NSQU7UG6S41                                 Ensco Plc
#
#         Registration.RegistrationStatus
# 92756                         DUPLICATE
# 110511                        DUPLICATE
# 117233                        DUPLICATE
# 140006                        DUPLICATE
# 769036                        DUPLICATE
# 769424                        DUPLICATE
# 994623                        DUPLICATE
# 1067553                       DUPLICATE
# 1190418                       DUPLICATE
# 1729864                       DUPLICATE

# %% [markdown]
# ### Levenshtein similarity

# %%
#Creating all posible pairs of Entity.Name
legal_name = pd.DataFrame(combinations_with_replacement(test_data['LEI'], 2), columns=["LEI.Ori","LEI.Dup"])
legal_name = legal_name[legal_name['LEI.Ori']!=legal_name['LEI.Dup']]

legal_name = pd.merge(legal_name,test_data, left_on='LEI.Ori', right_on='LEI',how='left')
legal_name = pd.merge(legal_name.drop('LEI',axis=1),test_data, left_on='LEI.Dup', right_on='LEI',how='left', suffixes=('.Ori','.Dup'))
legal_name = legal_name.drop('LEI',axis=1)

legal_name = legal_name.reindex(columns=['LEI.Ori', 
                      'Entity.LegalName.Ori',
                      'Registration.RegistrationStatus.Ori',
                      'LEI.Dup', 
                      'Entity.LegalName.Dup',
                      'Registration.RegistrationStatus.Dup'])

# %%
#Lev_ratio on token level
legal_name["LevScore"] = legal_name.apply(lambda x: fuzz.token_sort_ratio(x['Entity.LegalName.Ori'].lower(),x['Entity.LegalName.Dup'].lower()), axis=1)

#min_lev = legal_name.groupby('id1').min()
legal_name[legal_name['LevScore']==100]
# Out:
#                       LEI.Ori                   Entity.LegalName.Ori  \
# 1180602  21380048ADXM6Z67CT18                         RENISHAW P L C
# 4982142  213800HP3XUS3KTGWT63                     D4T4 SOLUTIONS PLC
# 5123817  213800I841D2RKMFK955                          N4 PHARMA PLC
# 6045312  213800MA2ZN22I4ITA79                   PRESIDENT ENERGY PLC
# 7254754  213800TB53ELEUKM7Q61  VODAFONE GROUP PUBLIC LIMITED COMPANY
# 8249712  549300G5FDS8FKPXPZ37                      Bristol Water PLC
# 8430614  7N0UJMJLXD0MDT5D5086                              Ensco PLC
#
#         Registration.RegistrationStatus.Ori               LEI.Dup  \
# 1180602                              ISSUED  5493001W2FMNF0GV7B53
# 4982142                              ISSUED  984500DJF88E9FFCA882
# 5123817                              ISSUED  213800OIN8T68PM7HK77
# 6045312                              ISSUED  549300HXJ164L1L8IM53
# 7254754                              ISSUED  549300MSQV80HSATBG53
# 8249712                              LAPSED  549300V0DVQGSADLDB82
# 8430614                              LAPSED  8YXIFWJW5NSQU7UG6S41
#
#                           Entity.LegalName.Dup  \
# 1180602                         Renishaw P L C
# 4982142                     D4T4 SOLUTIONS PLC
# 5123817                          N4 PHARMA PLC
# 6045312                   President Energy PLC
# 7254754  Vodafone Group Public Limited Company
# 8249712                      Bristol Water PLC
# 8430614                              Ensco Plc
#
#         Registration.RegistrationStatus.Dup  LevScore
# 1180602                           DUPLICATE       100
# 4982142                              ISSUED       100
# 5123817                           DUPLICATE       100
# 6045312                           DUPLICATE       100
# 7254754                           DUPLICATE       100
# 8249712                           DUPLICATE       100
# 8430614                           DUPLICATE       100

# %% [markdown]
# ### N-Gram & Cosine Similarity

# %%
import re
# N-Grams
def ngrams(string, n=3):
    string = re.sub(r'[,-./]|\s+',r'', string)
    ngrams = zip(*[string[i:] for i in range(n)])
    return [''.join(ngram) for ngram in ngrams]

print(ngrams('TANGENT COMMUNICATIONS PLC'))
# Out:
# ['TAN', 'ANG', 'NGE', 'GEN', 'ENT', 'NTC', 'TCO', 'COM', 'OMM', 'MMU', 'MUN', 'UNI', 'NIC', 'ICA', 'CAT', 'ATI', 'TIO', 'ION', 'ONS', 'NSP', 'SPL', 'PLC']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

text = [x for x in test_data["Entity.LegalName"].str.lower()]
vectorizer = TfidfVectorizer(min_df=1, analyzer=ngrams)
tf_idf_matrix = vectorizer.fit_transform(text).toarray()

vectors = [t for t in tf_idf_matrix]
out = cosine_similarity(vectors)
# set cosine of themselve = 0 
np.fill_diagonal(out,0)
max_cos = np.amax(out, axis = 1)
max_ind = np.argmax(out, axis = 1)

test_data_cosine = test_data.copy()
#reset index to join on max cosine score
test_data_cosine.index = range(test_data_cosine.shape[0])

test_data_cosine['Cosine'] = max_cos.tolist()
test_data_cosine['Index.Dup'] = max_ind.tolist()

#join original data
cosine_df = pd.merge(test_data_cosine, test_data_cosine.loc[:,['LEI','Entity.LegalName','Registration.RegistrationStatus']], 
                     left_on='Index.Dup', right_index=True, 
                     how = 'left',
                     suffixes=('.Ori', '.Dup'))

#Remove the Ori - Dup reverse relationship
cosine_df['Index.Ori'] = cosine_df.index
### Get Unique combo Index
filter_index = cosine_df[['Index.Ori','Index.Dup']]
filter_index = pd.DataFrame(np.sort(filter_index.values, axis=1), columns=filter_index.columns).drop_duplicates()

cosine_df = pd.merge(cosine_df,filter_index[['Index.Ori']], how = 'inner', on ='Index.Ori').drop_duplicates()
cosine_df.sort_values(by='Cosine',ascending = False) 

#Set Cut-Off Threshold for cosine
cosine_df_out= cosine_df[cosine_df['Cosine']>0.98]
cosine_df_out
# Out:
#                    LEI.Ori                   Entity.LegalName.Ori  \
# 456   21380048ADXM6Z67CT18                         RENISHAW P L C
# 1894  213800HP3XUS3KTGWT63                     D4T4 SOLUTIONS PLC
# 1931  213800I841D2RKMFK955                          N4 PHARMA PLC
# 2263  213800MA2ZN22I4ITA79                   PRESIDENT ENERGY PLC
# 2674  213800TB53ELEUKM7Q61  VODAFONE GROUP PUBLIC LIMITED COMPANY
# 3055  549300G5FDS8FKPXPZ37                      Bristol Water PLC
# 3190  7N0UJMJLXD0MDT5D5086                              Ensco PLC
#
#      Registration.RegistrationStatus.Ori  Cosine  Index.Dup  \
# 456                               ISSUED     1.0       3295
# 1894                              ISSUED     1.0       4018
# 1931                              ISSUED     1.0       2143
# 2263                              ISSUED     1.0       3488
# 2674                              ISSUED     1.0       3555
# 3055                              LAPSED     1.0       3661
# 3190                              LAPSED     1.0       3933
#
#                    LEI.Dup                   Entity.LegalName.Dup  \
# 456   5493001W2FMNF0GV7B53                         Renishaw P L C
# 1894  984500DJF88E9FFCA882                     D4T4 SOLUTIONS PLC
# 1931  213800OIN8T68PM7HK77                          N4 PHARMA PLC
# 2263  549300HXJ164L1L8IM53                   President Energy PLC
# 2674  549300MSQV80HSATBG53  Vodafone Group Public Limited Company
# 3055  549300V0DVQGSADLDB82                      Bristol Water PLC
# 3190  8YXIFWJW5NSQU7UG6S41                              Ensco Plc
#
#      Registration.RegistrationStatus.Dup  Index.Ori
# 456                            DUPLICATE        297
# 1894                              ISSUED       1475
# 1931                           DUPLICATE       1530
# 2263                           DUPLICATE       1915
# 2674                           DUPLICATE       2560
# 3055                           DUPLICATE       3464
# 3190                           DUPLICATE       3869

# %%
#Cannot define duplicate
dup_test_data[~dup_test_data['LEI'].isin(cosine_df_out['LEI.Dup'].tolist())]
# Out:
#                          LEI                          Entity.LegalName  \
# 92756   213800GBJ1RNNUKP2182                                OROGEN PLC
# 110511  213800JEFWNMHV4VS596                         TOPAZ FINANCE PLC
# 117233  213800KJWSAW2912ZP76  MANCHESTER & LONDON INVESTMENT TRUST PLC
# 769424  5493001WZIZE0GTD2X45       Tobermore Concrete Products Limited
#
#        Registration.RegistrationStatus
# 92756                        DUPLICATE
# 110511                       DUPLICATE
# 117233                       DUPLICATE
# 769424                       DUPLICATE

# %% [markdown]
# #### Other features to identify duplicate

# %% [markdown]
# "Entity.LegalJurisdiction", "Entity.EntityCategory", "Entity.LegalAddress"
#
# "RegistrationAuthorityID"

# %%
col_extra = ['LEI',
        'Entity.LegalName',
        'Entity.LegalJurisdiction',
        'Entity.LegalForm.EntityLegalFormCode',
        'Entity.EntityStatus',
        'Entity.RegistrationAuthority.RegistrationAuthorityEntityID',
        'Entity.EntityCategory',
        'Registration.RegistrationStatus',
        'Entity.LegalAddress.FirstAddressLine',
        'Entity.LegalAddress.City',
        'Entity.LegalAddress.Region',
        'Entity.LegalAddress.Country',
        'Entity.HeadquartersAddress.FirstAddressLine',
        'Entity.HeadquartersAddress.City',
        'Entity.HeadquartersAddress.Region',
        'Entity.HeadquartersAddress.Country']

data_extra = pd.read_csv('20220401-0800-gleif-goldencopy-lei2-golden-copy.csv.zip', compression='zip', usecols = col_extra,dtype='unicode')

# %%
all_dup = pd.concat([cosine_df_out['LEI.Ori'], cosine_df_out['LEI.Dup']]).drop_duplicates().tolist()
data_extra[data_extra["LEI"].isin(all_dup)].sort_values('Entity.LegalName')
# Out:
#                           LEI                       Entity.LegalName  \
# 968020   549300G5FDS8FKPXPZ37                      Bristol Water PLC
# 1190418  549300V0DVQGSADLDB82                      Bristol Water PLC
# 100840   213800HP3XUS3KTGWT63                     D4T4 SOLUTIONS PLC
# 2065311  984500DJF88E9FFCA882                     D4T4 SOLUTIONS PLC
# 1480367  7N0UJMJLXD0MDT5D5086                              Ensco PLC
# 1729864  8YXIFWJW5NSQU7UG6S41                              Ensco Plc
# 103679   213800I841D2RKMFK955                          N4 PHARMA PLC
# 140006   213800OIN8T68PM7HK77                          N4 PHARMA PLC
# 127155   213800MA2ZN22I4ITA79                   PRESIDENT ENERGY PLC
# 994623   549300HXJ164L1L8IM53                   President Energy PLC
# 22768    21380048ADXM6Z67CT18                         RENISHAW P L C
# 769036   5493001W2FMNF0GV7B53                         Renishaw P L C
# 167651   213800TB53ELEUKM7Q61  VODAFONE GROUP PUBLIC LIMITED COMPANY
# 1067553  549300MSQV80HSATBG53  Vodafone Group Public Limited Company
#
#                       Entity.LegalAddress.FirstAddressLine  \
# 968020                                     Bridgwater Road
# 1190418                                    Bridgwater Road
# 100840                                      Windmill House
# 2065311  First Floor, RR Tower IV, T.V.K. Industrial Es...
# 1480367                                          3rd Floor
# 1729864                             6 Chesterfield Gardens
# 103679                                           6TH FLOOR
# 140006                               60 GRACECHURCH STREET
# 127155                                       CARRWOOD PARK
# 994623                                      11 Hill Street
# 22768                                            NEW MILLS
# 769036                                           New Mills
# 167651                                      VODAFONE HOUSE
# 1067553                                     Vodafone House
#
#         Entity.LegalAddress.City Entity.LegalAddress.Region  \
# 968020                   Bristol                     GB-BST
# 1190418                  Bristol                     GB-ENG
# 100840         Sunbury-on-Thames                        NaN
# 2065311                  CHENNAI                      IN-TN
# 1480367                   London                     GB-EAL
# 1729864                   London                        NaN
# 103679                    LONDON                     GB-LND
# 140006                    LONDON                     GB-LND
# 127155                     LEEDS                     GB-LDS
# 994623                    London                        NaN
# 22768          WOTTON UNDER EDGE                     GB-GLS
# 769036         Wotton under Edge                        NaN
# 167651                   NEWBURY                        NaN
# 1067553                  Newbury                        NaN
#
#         Entity.LegalAddress.Country  \
# 968020                           GB
# 1190418                          GB
# 100840                           GB
# 2065311                          IN
# 1480367                          GB
# 1729864                          GB
# 103679                           GB
# 140006                           GB
# 127155                           GB
# 994623                           GB
# 22768                            GB
# 769036                           GB
# 167651                           GB
# 1067553                          GB
#
#         Entity.HeadquartersAddress.FirstAddressLine  \
# 968020                                   PO Box 218
# 1190418                             Bridgwater Road
# 100840                               Windmill House
# 2065311                         91-93 WINDMILL ROAD
# 1480367                                   3rd Floor
# 1729864                      6 Chesterfield Gardens
# 103679                                    6TH FLOOR
# 140006                                 WESTON HOUSE
# 127155                                CARRWOOD PARK
# 994623                               11 Hill Street
# 22768                                     NEW MILLS
# 769036                                    New Mills
# 167651                               VODAFONE HOUSE
# 1067553                              Vodafone House
#
#         Entity.HeadquartersAddress.City Entity.HeadquartersAddress.Region  \
# 968020                          Bristol                            GB-BST
# 1190418                         Bristol                            GB-ENG
# 100840                Sunbury-on-Thames                               NaN
# 2065311               Sunbury-on-Thames                            GB-SRY
# 1480367                          London                            GB-EAL
# 1729864                          London                               NaN
# 103679                           LONDON                            GB-LND
# 140006                            DERBY                            GB-DER
# 127155                            LEEDS                            GB-LDS
# 994623                           London                               NaN
# 22768                 WOTTON UNDER EDGE                            GB-GLS
# 769036                Wotton under Edge                               NaN
# 167651                          NEWBURY                               NaN
# 1067553                         Newbury                               NaN
#
#         Entity.HeadquartersAddress.Country  \
# 968020                                  GB
# 1190418                                 GB
# 100840                                  GB
# 2065311                                 GB
# 1480367                                 GB
# 1729864                                 GB
# 103679                                  GB
# 140006                                  GB
# 127155                                  GB
# 994623                                  GB
# 22768                                   GB
# 769036                                  GB
# 167651                                  GB
# 1067553                                 GB
#
#         Entity.RegistrationAuthority.RegistrationAuthorityEntityID  \
# 968020                                            02662226
# 1190418                                           02662226
# 100840                                            01892751
# 2065311                                             F04628
# 1480367                                           07023598
# 1729864                                                NaN
# 103679                                            01435584
# 140006                                            01435584
# 127155                                            05104249
# 994623                                            05104249
# 22768                                             01106260
# 769036                                            01106260
# 167651                                            01833679
# 1067553                                           01833679
#
#         Entity.LegalJurisdiction Entity.EntityCategory  \
# 968020                        GB               GENERAL
# 1190418                       GB               GENERAL
# 100840                        GB               GENERAL
# 2065311                       GB                BRANCH
# 1480367                       GB               GENERAL
# 1729864                       GB               GENERAL
# 103679                        GB               GENERAL
# 140006                        GB               GENERAL
# 127155                        GB               GENERAL
# 994623                        GB               GENERAL
# 22768                         GB               GENERAL
# 769036                        GB               GENERAL
# 167651                        GB               GENERAL
# 1067553                       GB               GENERAL
#
#         Entity.LegalForm.EntityLegalFormCode Entity.EntityStatus  \
# 968020                                  B6ES              ACTIVE
# 1190418                                 B6ES                 NaN
# 100840                                  B6ES              ACTIVE
# 2065311                                 B6ES              ACTIVE
# 1480367                                 B6ES              ACTIVE
# 1729864                                 B6ES                 NaN
# 103679                                  B6ES              ACTIVE
# 140006                                  B6ES                 NaN
# 127155                                  B6ES              ACTIVE
# 994623                                  B6ES                 NaN
# 22768                                   B6ES              ACTIVE
# 769036                                  B6ES                 NaN
# 167651                                  B6ES              ACTIVE
# 1067553                                 B6ES                 NaN
#
#         Registration.RegistrationStatus
# 968020                           LAPSED
# 1190418                       DUPLICATE
# 100840                           ISSUED
# 2065311                          ISSUED
# 1480367                          LAPSED
# 1729864                       DUPLICATE
# 103679                           ISSUED
# 140006                        DUPLICATE
# 127155                           ISSUED
# 994623                        DUPLICATE
# 22768                            ISSUED
# 769036                        DUPLICATE
# 167651                           ISSUED
# 1067553                       DUPLICATE

# %% [markdown]
# "Entity.LegalJurisdiction"
# "Entity.EntityCategory"
# "Entity.LegalAddress"
#
# "RegistrationAuthorityID"
